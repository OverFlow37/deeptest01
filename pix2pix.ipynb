# %%
import os

train_path = os.getenv('HOME')+'/aiffel/Exploration19/cityscapes/train/'
print("number of train examples :", len(os.listdir(train_path)))
val_path = os.getenv('HOME')+'/aiffel/Exploration19/cityscapes/val/'
print("number of val examples :", len(os.listdir(val_path)))
# Out:
# number of train examples : 1000
# number of val examples : 5

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = train_path + os.listdir(train_path)[np.random.randint(1000)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
f = train_path + os.listdir(train_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    truth = img[:, :w, :] 
    truth = tf.cast(truth, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(truth), normalize(colored)

f = train_path + os.listdir(train_path)[1]
truth, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(truth))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]   

print("✅")
# Out:
# ✅

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(truth, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(train_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %%
from tensorflow.keras import layers, Input, Model
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)
    
print("✅")
# Out:
# ✅

# %%
class Encoder(layers.Layer):
    def __init__(self):
        super(Encoder, self).__init__()
        filters = [64,128,256,512,512,512,512,512]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i == 0:
                self.blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.blocks.append(EncodeBlock(f))
    
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
    
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("✅")
# Out:
# ✅

# %%
Encoder().get_summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encode_block (EncodeBlock)   (None, 128, 128, 64)      3072
# _________________________________________________________________
# encode_block_1 (EncodeBlock) (None, 64, 64, 128)       131584
# _________________________________________________________________
# encode_block_2 (EncodeBlock) (None, 32, 32, 256)       525312
# _________________________________________________________________
# encode_block_3 (EncodeBlock) (None, 16, 16, 512)       2099200
# _________________________________________________________________
# encode_block_4 (EncodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# encode_block_5 (EncodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# encode_block_6 (EncodeBlock) (None, 2, 2, 512)         4196352
# _________________________________________________________________
# encode_block_7 (EncodeBlock) (None, 1, 1, 512)         4196352
# =================================================================
# Total params: 19,544,576
# Trainable params: 19,538,688
# Non-trainable params: 5,888
# _________________________________________________________________

# %%
class Decoder(layers.Layer):
    def __init__(self):
        super(Decoder, self).__init__()
        filters = [512,512,512,512,256,128,64]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i < 3:
                self.blocks.append(DecodeBlock(f))
            else:
                self.blocks.append(DecodeBlock(f, dropout=False))
                
        self.blocks.append(layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False))
        
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
            
    def get_summary(self, input_shape=(1,1,512)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
        
print("✅")
# Out:
# ✅

# %%
Decoder().get_summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1, 1, 512)]       0
# _________________________________________________________________
# decode_block (DecodeBlock)   (None, 2, 2, 512)         4196352
# _________________________________________________________________
# decode_block_1 (DecodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# decode_block_2 (DecodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# decode_block_3 (DecodeBlock) (None, 16, 16, 512)       4196352
# _________________________________________________________________
# decode_block_4 (DecodeBlock) (None, 32, 32, 256)       2098176
# _________________________________________________________________
# decode_block_5 (DecodeBlock) (None, 64, 64, 128)       524800
# _________________________________________________________________
# decode_block_6 (DecodeBlock) (None, 128, 128, 64)      131328
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 256, 256, 3)       3072
# =================================================================
# Total params: 19,542,784
# Trainable params: 19,537,792
# Non-trainable params: 4,992
# _________________________________________________________________

# %%
class EncoderDecoderGenerator(Model):
    def __init__(self):
        super(EncoderDecoderGenerator, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
    
    def call(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
   
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
        

EncoderDecoderGenerator().get_summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encoder_1 (Encoder)          (None, 1, 1, 512)         19544576
# _________________________________________________________________
# decoder_1 (Decoder)          (None, 256, 256, 3)       19542784
# =================================================================
# Total params: 39,087,360
# Trainable params: 39,076,480
# Non-trainable params: 10,880
# _________________________________________________________________

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("✅")
# Out:
# ✅

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block_16 (EncodeBlock)   (None, 128, 128, 64) 3072        input_4[0][0]
# __________________________________________________________________________________________________
# encode_block_17 (EncodeBlock)   (None, 64, 64, 128)  131584      encode_block_16[0][0]
# __________________________________________________________________________________________________
# encode_block_18 (EncodeBlock)   (None, 32, 32, 256)  525312      encode_block_17[0][0]
# __________________________________________________________________________________________________
# encode_block_19 (EncodeBlock)   (None, 16, 16, 512)  2099200     encode_block_18[0][0]
# __________________________________________________________________________________________________
# encode_block_20 (EncodeBlock)   (None, 8, 8, 512)    4196352     encode_block_19[0][0]
# __________________________________________________________________________________________________
# encode_block_21 (EncodeBlock)   (None, 4, 4, 512)    4196352     encode_block_20[0][0]
# __________________________________________________________________________________________________
# encode_block_22 (EncodeBlock)   (None, 2, 2, 512)    4196352     encode_block_21[0][0]
# __________________________________________________________________________________________________
# encode_block_23 (EncodeBlock)   (None, 1, 1, 512)    4196352     encode_block_22[0][0]
# __________________________________________________________________________________________________
# decode_block_14 (DecodeBlock)   (None, 2, 2, 512)    4196352     encode_block_23[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block_14[0][0]
#                                                                  encode_block_22[0][0]
# __________________________________________________________________________________________________
# decode_block_15 (DecodeBlock)   (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_15[0][0]
#                                                                  encode_block_21[0][0]
# __________________________________________________________________________________________________
# decode_block_16 (DecodeBlock)   (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_16[0][0]
#                                                                  encode_block_20[0][0]
# __________________________________________________________________________________________________
# decode_block_17 (DecodeBlock)   (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_17[0][0]
#                                                                  encode_block_19[0][0]
# __________________________________________________________________________________________________
# decode_block_18 (DecodeBlock)   (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_18[0][0]
#                                                                  encode_block_18[0][0]
# __________________________________________________________________________________________________
# decode_block_19 (DecodeBlock)   (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_19[0][0]
#                                                                  encode_block_17[0][0]
# __________________________________________________________________________________________________
# decode_block_20 (DecodeBlock)   (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_20[0][0]
#                                                                  encode_block_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x 

print("✅")
# Out:
# ✅

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()
    
print("✅")
# Out:
# ✅

# %%
Discriminator().get_summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_6[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

print("✅")
# Out:
# ✅

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

print("✅")
# Out:
# ✅

# %%
@tf.function
def train_step(truth, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(truth, training=True)
        # Discriminator 예측
        fake_disc = discriminator(truth, fake_colored, training=True)
        real_disc = discriminator(truth, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

print("✅")
# Out:
# ✅

# %%
EPOCHS = 100

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (truth, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(truth, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:1.0195
# L1_loss:0.3240
# Discriminator_loss:1.4161
#
# EPOCH[1] - STEP[20]
# Generator_loss:1.1171
# L1_loss:0.2884
# Discriminator_loss:1.0047
#
# EPOCH[1] - STEP[30]
# Generator_loss:1.3417
# L1_loss:0.3186
# Discriminator_loss:0.7670
#
# EPOCH[1] - STEP[40]
# Generator_loss:1.7549
# L1_loss:0.2453
# Discriminator_loss:0.6649
#
# EPOCH[1] - STEP[50]
# Generator_loss:1.7214
# L1_loss:0.2499
# Discriminator_loss:0.6276
#
# EPOCH[1] - STEP[60]
# Generator_loss:1.7632
# L1_loss:0.2991
# Discriminator_loss:0.6599
#
# EPOCH[1] - STEP[70]
# Generator_loss:1.7894
# L1_loss:0.2838
# Discriminator_loss:0.6167
#
# EPOCH[1] - STEP[80]
# Generator_loss:1.5579
# L1_loss:0.2533
# Discriminator_loss:0.5364
#
# EPOCH[1] - STEP[90]
# Generator_loss:1.8728
# L1_loss:0.2990
# Discriminator_loss:0.4976
#
# EPOCH[1] - STEP[100]
# Generator_loss:1.6474
# L1_loss:0.2716
# Discriminator_loss:0.5909
#
# EPOCH[1] - STEP[110]
# Generator_loss:2.0292
# L1_loss:0.2130
# Discriminator_loss:0.6397
#
# EPOCH[1] - STEP[120]
# Generator_loss:1.7474
# L1_loss:0.2286
# Discriminator_loss:1.3873
#
# EPOCH[1] - STEP[130]
# Generator_loss:1.9059
# L1_loss:0.2061
# Discriminator_loss:0.9180
#
# EPOCH[1] - STEP[140]
# Generator_loss:2.7087
# L1_loss:0.2758
# Discriminator_loss:0.7408
#
# EPOCH[1] - STEP[150]
# Generator_loss:1.6614
# L1_loss:0.2146
# Discriminator_loss:0.6251
#
# EPOCH[1] - STEP[160]
# Generator_loss:1.4822
# L1_loss:0.2451
# Discriminator_loss:0.7759
#
# EPOCH[1] - STEP[170]
# Generator_loss:1.5744
# L1_loss:0.2407
# Discriminator_loss:0.5014
#
# EPOCH[1] - STEP[180]
# Generator_loss:1.2283
# L1_loss:0.2343
# Discriminator_loss:0.8836
#
# EPOCH[1] - STEP[190]
# Generator_loss:0.1952
# L1_loss:0.2412
# Discriminator_loss:2.2999
#
# EPOCH[1] - STEP[200]
# Generator_loss:2.3651
# L1_loss:0.1928
# Discriminator_loss:0.4729
#
# EPOCH[1] - STEP[210]
# Generator_loss:2.0123
# L1_loss:0.2386
# Discriminator_loss:0.5022
#
# EPOCH[1] - STEP[220]
# Generator_loss:2.6751
# L1_loss:0.1851
# Discriminator_loss:1.0451
#
# EPOCH[1] - STEP[230]
# Generator_loss:2.0480
# L1_loss:0.1990
# Discriminator_loss:0.6127
#
# EPOCH[1] - STEP[240]
# Generator_loss:2.3552
# L1_loss:0.1808
# Discriminator_loss:1.3020
#
# EPOCH[1] - STEP[250]
# Generator_loss:1.9054
# L1_loss:0.2372
# Discriminator_loss:0.8609
#
# EPOCH[2] - STEP[10]
# Generator_loss:2.4414
# L1_loss:0.2148
# Discriminator_loss:0.5935
#
# EPOCH[2] - STEP[20]
# Generator_loss:2.0366
# L1_loss:0.2011
# Discriminator_loss:0.7411
#
# EPOCH[2] - STEP[30]
# Generator_loss:1.4169
# L1_loss:0.2412
# Discriminator_loss:0.6436
#
# EPOCH[2] - STEP[40]
# Generator_loss:2.0105
# L1_loss:0.2090
# Discriminator_loss:0.9556
#
# EPOCH[2] - STEP[50]
# Generator_loss:2.3478
# L1_loss:0.2157
# Discriminator_loss:0.7289
#
# EPOCH[2] - STEP[60]
# Generator_loss:1.7311
# L1_loss:0.2119
# Discriminator_loss:0.4733
#
# EPOCH[2] - STEP[70]
# Generator_loss:0.8073
# L1_loss:0.2258
# Discriminator_loss:1.5931
#
# EPOCH[2] - STEP[80]
# Generator_loss:1.6340
# L1_loss:0.2571
# Discriminator_loss:0.5781
#
# EPOCH[2] - STEP[90]
# Generator_loss:1.8055
# L1_loss:0.2185
# Discriminator_loss:0.5933
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.7255
# L1_loss:0.2160
# Discriminator_loss:1.3090
#
# EPOCH[2] - STEP[110]
# Generator_loss:2.0371
# L1_loss:0.2071
# Discriminator_loss:0.4645
#
# EPOCH[2] - STEP[120]
# Generator_loss:1.2552
# L1_loss:0.2556
# Discriminator_loss:1.4854
#
# EPOCH[2] - STEP[130]
# Generator_loss:1.4246
# L1_loss:0.2200
# Discriminator_loss:0.5821
#
# EPOCH[2] - STEP[140]
# Generator_loss:1.2706
# L1_loss:0.2166
# Discriminator_loss:0.5783
#
# EPOCH[2] - STEP[150]
# Generator_loss:1.9229
# L1_loss:0.2096
# Discriminator_loss:0.3790
#
# EPOCH[2] - STEP[160]
# Generator_loss:3.5661
# L1_loss:0.2020
# Discriminator_loss:0.8145
#
# EPOCH[2] - STEP[170]
# Generator_loss:2.5178
# L1_loss:0.2099
# Discriminator_loss:1.3986
#
# EPOCH[2] - STEP[180]
# Generator_loss:2.9020
# L1_loss:0.2301
# Discriminator_loss:0.4511
#
# EPOCH[2] - STEP[190]
# Generator_loss:0.4253
# L1_loss:0.2517
# Discriminator_loss:1.3413
#
# EPOCH[2] - STEP[200]
# Generator_loss:2.3110
# L1_loss:0.1738
# Discriminator_loss:0.6590
#
# EPOCH[2] - STEP[210]
# Generator_loss:0.9950
# L1_loss:0.1752
# Discriminator_loss:0.9175
#
# EPOCH[2] - STEP[220]
# Generator_loss:1.1947
# L1_loss:0.2314
# Discriminator_loss:0.7221
#
# EPOCH[2] - STEP[230]
# Generator_loss:1.7539
# L1_loss:0.1872
# Discriminator_loss:0.5328
#
# EPOCH[2] - STEP[240]
# Generator_loss:1.9322
# L1_loss:0.1611
# Discriminator_loss:1.1522
#
# EPOCH[2] - STEP[250]
# Generator_loss:2.0163
# L1_loss:0.1813
# Discriminator_loss:0.8344
#
# EPOCH[3] - STEP[10]
# Generator_loss:1.1474
# L1_loss:0.2468
# Discriminator_loss:0.8426
#
# EPOCH[3] - STEP[20]
# Generator_loss:1.9185
# L1_loss:0.2316
# Discriminator_loss:0.4457
#
# EPOCH[3] - STEP[30]
# Generator_loss:1.7062
# L1_loss:0.2171
# Discriminator_loss:0.5692
#
# EPOCH[3] - STEP[40]
# Generator_loss:2.3665
# L1_loss:0.1952
# Discriminator_loss:1.2892
#
# EPOCH[3] - STEP[50]
# Generator_loss:1.5913
# L1_loss:0.1786
# Discriminator_loss:0.5606
#
# EPOCH[3] - STEP[60]
# Generator_loss:2.2970
# L1_loss:0.1916
# Discriminator_loss:0.4932
#
# EPOCH[3] - STEP[70]
# Generator_loss:2.7578
# L1_loss:0.1978
# Discriminator_loss:0.4862
#
# EPOCH[3] - STEP[80]
# Generator_loss:1.6700
# L1_loss:0.2049
# Discriminator_loss:0.5399
#
# EPOCH[3] - STEP[90]
# Generator_loss:2.3340
# L1_loss:0.2300
# Discriminator_loss:0.4034
#
# EPOCH[3] - STEP[100]
# Generator_loss:0.9496
# L1_loss:0.2408
# Discriminator_loss:1.0137
#
# EPOCH[3] - STEP[110]
# Generator_loss:1.6382
# L1_loss:0.1783
# Discriminator_loss:0.5514
#
# EPOCH[3] - STEP[120]
# Generator_loss:2.1483
# L1_loss:0.2155
# Discriminator_loss:0.4589
#
# EPOCH[3] - STEP[130]
# Generator_loss:1.1002
# L1_loss:0.2091
# Discriminator_loss:0.8165
#
# EPOCH[3] - STEP[140]
# Generator_loss:2.0138
# L1_loss:0.1810
# Discriminator_loss:2.3763
#
# EPOCH[3] - STEP[150]
# Generator_loss:1.1377
# L1_loss:0.2001
# Discriminator_loss:0.9405
#
# EPOCH[3] - STEP[160]
# Generator_loss:1.1556
# L1_loss:0.2253
# Discriminator_loss:0.8364
#
# EPOCH[3] - STEP[170]
# Generator_loss:1.1594
# L1_loss:0.1674
# Discriminator_loss:0.6517
#
# EPOCH[3] - STEP[180]
# Generator_loss:1.3460
# L1_loss:0.2570
# Discriminator_loss:0.9306
#
# EPOCH[3] - STEP[190]
# Generator_loss:0.7650
# L1_loss:0.2427
# Discriminator_loss:0.7721
#
# EPOCH[3] - STEP[200]
# Generator_loss:0.7792
# L1_loss:0.2163
# Discriminator_loss:0.8456
#
# EPOCH[3] - STEP[210]
# Generator_loss:1.3889
# L1_loss:0.1953
# Discriminator_loss:0.4720
#
# EPOCH[3] - STEP[220]
# Generator_loss:2.4014
# L1_loss:0.1905
# Discriminator_loss:0.6125
#
# EPOCH[3] - STEP[230]
# Generator_loss:2.0839
# L1_loss:0.1954
# Discriminator_loss:0.7089
#
# EPOCH[3] - STEP[240]
# Generator_loss:1.9737
# L1_loss:0.2117
# Discriminator_loss:1.1584
#
# EPOCH[3] - STEP[250]
# Generator_loss:2.4873
# L1_loss:0.2443
# Discriminator_loss:0.3553
#
# EPOCH[4] - STEP[10]
# Generator_loss:1.1869
# L1_loss:0.1826
# Discriminator_loss:1.1350
#
# EPOCH[4] - STEP[20]
# Generator_loss:1.6671
# L1_loss:0.2332
# Discriminator_loss:0.4254
#
# EPOCH[4] - STEP[30]
# Generator_loss:1.7090
# L1_loss:0.2191
# Discriminator_loss:0.5350
#
# EPOCH[4] - STEP[40]
# Generator_loss:2.5771
# L1_loss:0.2286
# Discriminator_loss:0.7798
#
# EPOCH[4] - STEP[50]
# Generator_loss:1.3162
# L1_loss:0.1892
# Discriminator_loss:0.5523
#
# EPOCH[4] - STEP[60]
# Generator_loss:1.0046
# L1_loss:0.2143
# Discriminator_loss:0.6932
#
# EPOCH[4] - STEP[70]
# Generator_loss:0.9866
# L1_loss:0.1950
# Discriminator_loss:0.7598
#
# EPOCH[4] - STEP[80]
# Generator_loss:2.1628
# L1_loss:0.1768
# Discriminator_loss:0.5367
#
# EPOCH[4] - STEP[90]
# Generator_loss:1.7674
# L1_loss:0.2244
# Discriminator_loss:0.5079
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.3559
# L1_loss:0.1711
# Discriminator_loss:0.8451
#
# EPOCH[4] - STEP[110]
# Generator_loss:1.0115
# L1_loss:0.2205
# Discriminator_loss:0.5545
#
# EPOCH[4] - STEP[120]
# Generator_loss:1.1084
# L1_loss:0.1968
# Discriminator_loss:0.5876
#
# EPOCH[4] - STEP[130]
# Generator_loss:0.8944
# L1_loss:0.2144
# Discriminator_loss:0.8564
#
# EPOCH[4] - STEP[140]
# Generator_loss:1.6600
# L1_loss:0.1769
# Discriminator_loss:0.5306
#
# EPOCH[4] - STEP[150]
# Generator_loss:0.4483
# L1_loss:0.2521
# Discriminator_loss:1.3849
#
# EPOCH[4] - STEP[160]
# Generator_loss:1.3599
# L1_loss:0.1571
# Discriminator_loss:0.7291
#
# EPOCH[4] - STEP[170]
# Generator_loss:2.6451
# L1_loss:0.1932
# Discriminator_loss:0.2615
#
# EPOCH[4] - STEP[180]
# Generator_loss:1.6955
# L1_loss:0.2195
# Discriminator_loss:0.7675
#
# EPOCH[4] - STEP[190]
# Generator_loss:2.6031
# L1_loss:0.2267
# Discriminator_loss:0.8451
#
# EPOCH[4] - STEP[200]
# Generator_loss:3.1993
# L1_loss:0.1947
# Discriminator_loss:1.3836
#
# EPOCH[4] - STEP[210]
# Generator_loss:0.9962
# L1_loss:0.2248
# Discriminator_loss:0.7831
#
# EPOCH[4] - STEP[220]
# Generator_loss:1.5608
# L1_loss:0.1948
# Discriminator_loss:0.9229
#
# EPOCH[4] - STEP[230]
# Generator_loss:1.4886
# L1_loss:0.2175
# Discriminator_loss:0.7705
#
# EPOCH[4] - STEP[240]
# Generator_loss:1.8474
# L1_loss:0.2041
# Discriminator_loss:0.7562
#
# EPOCH[4] - STEP[250]
# Generator_loss:1.9896
# L1_loss:0.2139
# Discriminator_loss:0.8503
#
# EPOCH[5] - STEP[10]
# Generator_loss:1.1783
# L1_loss:0.1888
# Discriminator_loss:0.8481
#
# EPOCH[5] - STEP[20]
# Generator_loss:1.7114
# L1_loss:0.2548
# Discriminator_loss:0.5269
#
# EPOCH[5] - STEP[30]
# Generator_loss:2.5543
# L1_loss:0.1700
# Discriminator_loss:0.6885
#
# EPOCH[5] - STEP[40]
# Generator_loss:2.4630
# L1_loss:0.1794
# Discriminator_loss:1.4972
#
# EPOCH[5] - STEP[50]
# Generator_loss:1.5883
# L1_loss:0.2024
# Discriminator_loss:0.4315
#
# EPOCH[5] - STEP[60]
# Generator_loss:2.2487
# L1_loss:0.1494
# Discriminator_loss:1.8499
#
# EPOCH[5] - STEP[70]
# Generator_loss:2.8465
# L1_loss:0.1572
# Discriminator_loss:1.2495
#
# EPOCH[5] - STEP[80]
# Generator_loss:2.0736
# L1_loss:0.1856
# Discriminator_loss:0.5241
#
# EPOCH[5] - STEP[90]
# Generator_loss:1.2211
# L1_loss:0.1836
# Discriminator_loss:0.8167
#
# EPOCH[5] - STEP[100]
# Generator_loss:2.9363
# L1_loss:0.2094
# Discriminator_loss:0.7967
#
# EPOCH[5] - STEP[110]
# Generator_loss:2.5212
# L1_loss:0.1829
# Discriminator_loss:1.3483
#
# EPOCH[5] - STEP[120]
# Generator_loss:1.3802
# L1_loss:0.2066
# Discriminator_loss:0.4657
#
# EPOCH[5] - STEP[130]
# Generator_loss:2.3621
# L1_loss:0.2047
# Discriminator_loss:1.5374
#
# EPOCH[5] - STEP[140]
# Generator_loss:1.1121
# L1_loss:0.1636
# Discriminator_loss:0.7017
#
# EPOCH[5] - STEP[150]
# Generator_loss:1.3880
# L1_loss:0.2226
# Discriminator_loss:0.8910
#
# EPOCH[5] - STEP[160]
# Generator_loss:1.8560
# L1_loss:0.1854
# Discriminator_loss:0.7815
#
# EPOCH[5] - STEP[170]
# Generator_loss:1.4781
# L1_loss:0.2330
# Discriminator_loss:0.4489
#
# EPOCH[5] - STEP[180]
# Generator_loss:1.0206
# L1_loss:0.2271
# Discriminator_loss:0.6180
#
# EPOCH[5] - STEP[190]
# Generator_loss:1.9069
# L1_loss:0.1895
# Discriminator_loss:0.4911
#
# EPOCH[5] - STEP[200]
# Generator_loss:2.5439
# L1_loss:0.1842
# Discriminator_loss:0.5844
#
# EPOCH[5] - STEP[210]
# Generator_loss:1.7120
# L1_loss:0.1971
# Discriminator_loss:0.4271
#
# EPOCH[5] - STEP[220]
# Generator_loss:0.9140
# L1_loss:0.1825
# Discriminator_loss:0.9714
#
# EPOCH[5] - STEP[230]
# Generator_loss:1.3995
# L1_loss:0.1993
# Discriminator_loss:0.6497
#
# EPOCH[5] - STEP[240]
# Generator_loss:0.9274
# L1_loss:0.2269
# Discriminator_loss:0.6811
#
# EPOCH[5] - STEP[250]
# Generator_loss:2.4620
# L1_loss:0.2174
# Discriminator_loss:0.4385
#
# EPOCH[6] - STEP[10]
# Generator_loss:1.3384
# L1_loss:0.1769
# Discriminator_loss:0.6875
#
# EPOCH[6] - STEP[20]
# Generator_loss:2.0745
# L1_loss:0.1219
# Discriminator_loss:2.0053
#
# EPOCH[6] - STEP[30]
# Generator_loss:1.9206
# L1_loss:0.2296
# Discriminator_loss:0.5908
#
# EPOCH[6] - STEP[40]
# Generator_loss:1.5477
# L1_loss:0.1881
# Discriminator_loss:0.7003
#
# EPOCH[6] - STEP[50]
# Generator_loss:1.5862
# L1_loss:0.2108
# Discriminator_loss:0.8732
#
# EPOCH[6] - STEP[60]
# Generator_loss:1.9436
# L1_loss:0.1899
# Discriminator_loss:0.7556
#
# EPOCH[6] - STEP[70]
# Generator_loss:2.0821
# L1_loss:0.1844
# Discriminator_loss:1.6812
#
# EPOCH[6] - STEP[80]
# Generator_loss:1.6601
# L1_loss:0.1984
# Discriminator_loss:0.6440
#
# EPOCH[6] - STEP[90]
# Generator_loss:3.0347
# L1_loss:0.1691
# Discriminator_loss:1.4345
#
# EPOCH[6] - STEP[100]
# Generator_loss:2.3888
# L1_loss:0.2025
# Discriminator_loss:1.2547
#
# EPOCH[6] - STEP[110]
# Generator_loss:0.9459
# L1_loss:0.1679
# Discriminator_loss:1.2574
#
# EPOCH[6] - STEP[120]
# Generator_loss:2.3770
# L1_loss:0.1651
# Discriminator_loss:0.4136
#
# EPOCH[6] - STEP[130]
# Generator_loss:1.7395
# L1_loss:0.2597
# Discriminator_loss:1.1280
#
# EPOCH[6] - STEP[140]
# Generator_loss:0.5735
# L1_loss:0.2126
# Discriminator_loss:1.1616
#
# EPOCH[6] - STEP[150]
# Generator_loss:2.9857
# L1_loss:0.2090
# Discriminator_loss:0.8221
#
# EPOCH[6] - STEP[160]
# Generator_loss:0.6973
# L1_loss:0.2032
# Discriminator_loss:1.0407
#
# EPOCH[6] - STEP[170]
# Generator_loss:2.6104
# L1_loss:0.1469
# Discriminator_loss:1.5161
#
# EPOCH[6] - STEP[180]
# Generator_loss:1.4598
# L1_loss:0.1874
# Discriminator_loss:0.5458
#
# EPOCH[6] - STEP[190]
# Generator_loss:1.2295
# L1_loss:0.1816
# Discriminator_loss:0.6022
#
# EPOCH[6] - STEP[200]
# Generator_loss:2.3289
# L1_loss:0.1819
# Discriminator_loss:0.4981
#
# EPOCH[6] - STEP[210]
# Generator_loss:2.4115
# L1_loss:0.1871
# Discriminator_loss:0.6567
#
# EPOCH[6] - STEP[220]
# Generator_loss:2.4273
# L1_loss:0.1580
# Discriminator_loss:0.6302
#
# EPOCH[6] - STEP[230]
# Generator_loss:1.3522
# L1_loss:0.2270
# Discriminator_loss:0.4977
#
# EPOCH[6] - STEP[240]
# Generator_loss:2.2966
# L1_loss:0.1560
# Discriminator_loss:0.7387
#
# EPOCH[6] - STEP[250]
# Generator_loss:1.0479
# L1_loss:0.2028
# Discriminator_loss:0.6502
#
# EPOCH[7] - STEP[10]
# Generator_loss:1.4289
# L1_loss:0.1644
# Discriminator_loss:0.8862
#
# EPOCH[7] - STEP[20]
# Generator_loss:3.4733
# L1_loss:0.1961
# Discriminator_loss:0.5994
#
# EPOCH[7] - STEP[30]
# Generator_loss:1.2837
# L1_loss:0.1988
# Discriminator_loss:0.7074
#
# EPOCH[7] - STEP[40]
# Generator_loss:1.5248
# L1_loss:0.2136
# Discriminator_loss:0.6168
#
# EPOCH[7] - STEP[50]
# Generator_loss:1.0213
# L1_loss:0.1912
# Discriminator_loss:0.6194
#
# EPOCH[7] - STEP[60]
# Generator_loss:0.2087
# L1_loss:0.2177
# Discriminator_loss:1.9394
#
# EPOCH[7] - STEP[70]
# Generator_loss:2.2625
# L1_loss:0.2076
# Discriminator_loss:0.7975
#
# EPOCH[7] - STEP[80]
# Generator_loss:1.9467
# L1_loss:0.1904
# Discriminator_loss:0.6631
#
# EPOCH[7] - STEP[90]
# Generator_loss:1.3459
# L1_loss:0.2028
# Discriminator_loss:1.4652
#
# EPOCH[7] - STEP[100]
# Generator_loss:1.2416
# L1_loss:0.2263
# Discriminator_loss:0.5812
#
# EPOCH[7] - STEP[110]
# Generator_loss:2.2482
# L1_loss:0.1903
# Discriminator_loss:1.5657
#
# EPOCH[7] - STEP[120]
# Generator_loss:2.7445
# L1_loss:0.2414
# Discriminator_loss:0.2256
#
# EPOCH[7] - STEP[130]
# Generator_loss:0.8019
# L1_loss:0.1721
# Discriminator_loss:1.0177
#
# EPOCH[7] - STEP[140]
# Generator_loss:0.7857
# L1_loss:0.2463
# Discriminator_loss:0.9069
#
# EPOCH[7] - STEP[150]
# Generator_loss:0.8900
# L1_loss:0.1885
# Discriminator_loss:0.6693
#
# EPOCH[7] - STEP[160]
# Generator_loss:2.5638
# L1_loss:0.2025
# Discriminator_loss:0.4299
#
# EPOCH[7] - STEP[170]
# Generator_loss:2.2317
# L1_loss:0.1941
# Discriminator_loss:0.5901
#
# EPOCH[7] - STEP[180]
# Generator_loss:1.7363
# L1_loss:0.1817
# Discriminator_loss:0.3349
#
# EPOCH[7] - STEP[190]
# Generator_loss:3.3433
# L1_loss:0.1758
# Discriminator_loss:0.5303
#
# EPOCH[7] - STEP[200]
# Generator_loss:2.3008
# L1_loss:0.1619
# Discriminator_loss:0.5831
#
# EPOCH[7] - STEP[210]
# Generator_loss:1.2890
# L1_loss:0.1983
# Discriminator_loss:0.9743
#
# EPOCH[7] - STEP[220]
# Generator_loss:2.2864
# L1_loss:0.1892
# Discriminator_loss:0.6482
#
# EPOCH[7] - STEP[230]
# Generator_loss:0.8506
# L1_loss:0.2004
# Discriminator_loss:0.8619
#
# EPOCH[7] - STEP[240]
# Generator_loss:1.3496
# L1_loss:0.1555
# Discriminator_loss:1.1353
#
# EPOCH[7] - STEP[250]
# Generator_loss:1.8190
# L1_loss:0.1480
# Discriminator_loss:0.8272
#
# EPOCH[8] - STEP[10]
# Generator_loss:1.4303
# L1_loss:0.2238
# Discriminator_loss:0.7617
#
# EPOCH[8] - STEP[20]
# Generator_loss:2.0259
# L1_loss:0.1748
# Discriminator_loss:1.0763
#
# EPOCH[8] - STEP[30]
# Generator_loss:2.2828
# L1_loss:0.1510
# Discriminator_loss:1.5777
#
# EPOCH[8] - STEP[40]
# Generator_loss:1.2623
# L1_loss:0.2161
# Discriminator_loss:0.4557
#
# EPOCH[8] - STEP[50]
# Generator_loss:1.1749
# L1_loss:0.1506
# Discriminator_loss:0.8919
#
# EPOCH[8] - STEP[60]
# Generator_loss:1.4527
# L1_loss:0.1631
# Discriminator_loss:0.9462
#
# EPOCH[8] - STEP[70]
# Generator_loss:2.0125
# L1_loss:0.2003
# Discriminator_loss:0.5091
#
# EPOCH[8] - STEP[80]
# Generator_loss:0.2026
# L1_loss:0.1725
# Discriminator_loss:2.4947
#
# EPOCH[8] - STEP[90]
# Generator_loss:1.1574
# L1_loss:0.1693
# Discriminator_loss:1.0151
#
# EPOCH[8] - STEP[100]
# Generator_loss:3.3568
# L1_loss:0.1684
# Discriminator_loss:0.4547
#
# EPOCH[8] - STEP[110]
# Generator_loss:1.7063
# L1_loss:0.1706
# Discriminator_loss:0.5329
#
# EPOCH[8] - STEP[120]
# Generator_loss:1.7102
# L1_loss:0.1786
# Discriminator_loss:0.7365
#
# EPOCH[8] - STEP[130]
# Generator_loss:3.1323
# L1_loss:0.2020
# Discriminator_loss:0.7488
#
# EPOCH[8] - STEP[140]
# Generator_loss:1.1746
# L1_loss:0.1886
# Discriminator_loss:0.7322
#
# EPOCH[8] - STEP[150]
# Generator_loss:1.6712
# L1_loss:0.1694
# Discriminator_loss:0.6393
#
# EPOCH[8] - STEP[160]
# Generator_loss:0.9177
# L1_loss:0.1332
# Discriminator_loss:1.1794
#
# EPOCH[8] - STEP[170]
# Generator_loss:1.0889
# L1_loss:0.1777
# Discriminator_loss:0.6565
#
# EPOCH[8] - STEP[180]
# Generator_loss:2.7540
# L1_loss:0.1478
# Discriminator_loss:0.8610
#
# EPOCH[8] - STEP[190]
# Generator_loss:1.1981
# L1_loss:0.1653
# Discriminator_loss:1.1008
#
# EPOCH[8] - STEP[200]
# Generator_loss:2.4402
# L1_loss:0.2099
# Discriminator_loss:0.4448
#
# EPOCH[8] - STEP[210]
# Generator_loss:1.1757
# L1_loss:0.1640
# Discriminator_loss:0.8268
#
# EPOCH[8] - STEP[220]
# Generator_loss:0.9271
# L1_loss:0.1916
# Discriminator_loss:0.8310
#
# EPOCH[8] - STEP[230]
# Generator_loss:1.9392
# L1_loss:0.1917
# Discriminator_loss:0.5976
#
# EPOCH[8] - STEP[240]
# Generator_loss:0.9366
# L1_loss:0.1774
# Discriminator_loss:0.8337
#
# EPOCH[8] - STEP[250]
# Generator_loss:1.9470
# L1_loss:0.1612
# Discriminator_loss:0.7902
#
# EPOCH[9] - STEP[10]
# Generator_loss:0.9277
# L1_loss:0.1778
# Discriminator_loss:1.0501
#
# EPOCH[9] - STEP[20]
# Generator_loss:1.2938
# L1_loss:0.1758
# Discriminator_loss:0.6154
#
# EPOCH[9] - STEP[30]
# Generator_loss:2.2184
# L1_loss:0.1847
# Discriminator_loss:0.3577
#
# EPOCH[9] - STEP[40]
# Generator_loss:2.1188
# L1_loss:0.2038
# Discriminator_loss:1.0448
#
# EPOCH[9] - STEP[50]
# Generator_loss:2.1018
# L1_loss:0.1512
# Discriminator_loss:0.6343
#
# EPOCH[9] - STEP[60]
# Generator_loss:1.8271
# L1_loss:0.2112
# Discriminator_loss:0.4669
#
# EPOCH[9] - STEP[70]
# Generator_loss:2.6311
# L1_loss:0.1532
# Discriminator_loss:1.5334
#
# EPOCH[9] - STEP[80]
# Generator_loss:1.8273
# L1_loss:0.2160
# Discriminator_loss:0.3568
#
# EPOCH[9] - STEP[90]
# Generator_loss:1.8714
# L1_loss:0.1385
# Discriminator_loss:0.8434
#
# EPOCH[9] - STEP[100]
# Generator_loss:1.5154
# L1_loss:0.1802
# Discriminator_loss:0.8831
#
# EPOCH[9] - STEP[110]
# Generator_loss:1.8368
# L1_loss:0.1917
# Discriminator_loss:0.3568
#
# EPOCH[9] - STEP[120]
# Generator_loss:2.2105
# L1_loss:0.1565
# Discriminator_loss:0.9710
#
# EPOCH[9] - STEP[130]
# Generator_loss:0.9375
# L1_loss:0.1632
# Discriminator_loss:1.0844
#
# EPOCH[9] - STEP[140]
# Generator_loss:2.6359
# L1_loss:0.1591
# Discriminator_loss:0.5842
#
# EPOCH[9] - STEP[150]
# Generator_loss:1.0385
# L1_loss:0.1935
# Discriminator_loss:0.6443
#
# EPOCH[9] - STEP[160]
# Generator_loss:1.9513
# L1_loss:0.2025
# Discriminator_loss:0.9839
#
# EPOCH[9] - STEP[170]
# Generator_loss:0.7023
# L1_loss:0.2068
# Discriminator_loss:1.1603
#
# EPOCH[9] - STEP[180]
# Generator_loss:1.3504
# L1_loss:0.2207
# Discriminator_loss:0.4307
#
# EPOCH[9] - STEP[190]
# Generator_loss:1.8919
# L1_loss:0.1882
# Discriminator_loss:0.4363
#
# EPOCH[9] - STEP[200]
# Generator_loss:1.8951
# L1_loss:0.1405
# Discriminator_loss:1.0605
#
# EPOCH[9] - STEP[210]
# Generator_loss:2.8303
# L1_loss:0.2052
# Discriminator_loss:0.2392
#
# EPOCH[9] - STEP[220]
# Generator_loss:1.2388
# L1_loss:0.1843
# Discriminator_loss:0.7542
#
# EPOCH[9] - STEP[230]
# Generator_loss:1.0953
# L1_loss:0.1731
# Discriminator_loss:0.8395
#
# EPOCH[9] - STEP[240]
# Generator_loss:1.7345
# L1_loss:0.1919
# Discriminator_loss:0.6521
#
# EPOCH[9] - STEP[250]
# Generator_loss:1.9013
# L1_loss:0.1943
# Discriminator_loss:0.4897
#
# EPOCH[10] - STEP[10]
# Generator_loss:1.6210
# L1_loss:0.1945
# Discriminator_loss:0.6134
#
# EPOCH[10] - STEP[20]
# Generator_loss:0.7689
# L1_loss:0.2410
# Discriminator_loss:1.1190
#
# EPOCH[10] - STEP[30]
# Generator_loss:1.5835
# L1_loss:0.1894
# Discriminator_loss:0.6685
#
# EPOCH[10] - STEP[40]
# Generator_loss:1.1969
# L1_loss:0.1921
# Discriminator_loss:0.6421
#
# EPOCH[10] - STEP[50]
# Generator_loss:1.9811
# L1_loss:0.2449
# Discriminator_loss:0.3388
#
# EPOCH[10] - STEP[60]
# Generator_loss:1.9889
# L1_loss:0.1667
# Discriminator_loss:0.4262
#
# EPOCH[10] - STEP[70]
# Generator_loss:1.5551
# L1_loss:0.1625
# Discriminator_loss:0.7305
#
# EPOCH[10] - STEP[80]
# Generator_loss:2.4131
# L1_loss:0.1771
# Discriminator_loss:0.9423
#
# EPOCH[10] - STEP[90]
# Generator_loss:2.9730
# L1_loss:0.2010
# Discriminator_loss:0.5144
#
# EPOCH[10] - STEP[100]
# Generator_loss:0.3351
# L1_loss:0.1948
# Discriminator_loss:1.8886
#
# EPOCH[10] - STEP[110]
# Generator_loss:1.0710
# L1_loss:0.1742
# Discriminator_loss:0.7657
#
# EPOCH[10] - STEP[120]
# Generator_loss:0.6758
# L1_loss:0.1705
# Discriminator_loss:0.9693
#
# EPOCH[10] - STEP[130]
# Generator_loss:1.8239
# L1_loss:0.2085
# Discriminator_loss:0.4463
#
# EPOCH[10] - STEP[140]
# Generator_loss:0.8910
# L1_loss:0.2095
# Discriminator_loss:0.7062
#
# EPOCH[10] - STEP[150]
# Generator_loss:1.1686
# L1_loss:0.1650
# Discriminator_loss:1.2056
#
# EPOCH[10] - STEP[160]
# Generator_loss:2.8926
# L1_loss:0.1592
# Discriminator_loss:1.2876
#
# EPOCH[10] - STEP[170]
# Generator_loss:1.7398
# L1_loss:0.2262
# Discriminator_loss:0.5842
#
# EPOCH[10] - STEP[180]
# Generator_loss:2.3757
# L1_loss:0.1912
# Discriminator_loss:0.4833
#
# EPOCH[10] - STEP[190]
# Generator_loss:1.2297
# L1_loss:0.1756
# Discriminator_loss:0.7884
#
# EPOCH[10] - STEP[200]
# Generator_loss:2.0102
# L1_loss:0.1754
# Discriminator_loss:0.3617
#
# EPOCH[10] - STEP[210]
# Generator_loss:1.2772
# L1_loss:0.2282
# Discriminator_loss:0.5385
#
# EPOCH[10] - STEP[220]
# Generator_loss:1.3936
# L1_loss:0.2143
# Discriminator_loss:0.9705
#
# EPOCH[10] - STEP[230]
# Generator_loss:0.6036
# L1_loss:0.1487
# Discriminator_loss:1.3662
#
# EPOCH[10] - STEP[240]
# Generator_loss:0.8211
# L1_loss:0.1503
# Discriminator_loss:0.8753
#
# EPOCH[10] - STEP[250]
# Generator_loss:0.4305
# L1_loss:0.2176
# Discriminator_loss:1.3828
#
# EPOCH[11] - STEP[10]
# Generator_loss:1.4667
# L1_loss:0.1457
# Discriminator_loss:0.6812
#
# EPOCH[11] - STEP[20]
# Generator_loss:1.6441
# L1_loss:0.1598
# Discriminator_loss:0.5845
#
# EPOCH[11] - STEP[30]
# Generator_loss:2.1337
# L1_loss:0.1492
# Discriminator_loss:0.3379
#
# EPOCH[11] - STEP[40]
# Generator_loss:1.9149
# L1_loss:0.2223
# Discriminator_loss:0.2942
#
# EPOCH[11] - STEP[50]
# Generator_loss:0.3042
# L1_loss:0.1837
# Discriminator_loss:1.8384
#
# EPOCH[11] - STEP[60]
# Generator_loss:1.1690
# L1_loss:0.2005
# Discriminator_loss:0.6020
#
# EPOCH[11] - STEP[70]
# Generator_loss:1.7960
# L1_loss:0.1898
# Discriminator_loss:0.3409
#
# EPOCH[11] - STEP[80]
# Generator_loss:2.6102
# L1_loss:0.1941
# Discriminator_loss:0.3267
#
# EPOCH[11] - STEP[90]
# Generator_loss:2.2926
# L1_loss:0.1680
# Discriminator_loss:2.0064
#
# EPOCH[11] - STEP[100]
# Generator_loss:1.5346
# L1_loss:0.1492
# Discriminator_loss:0.8081
#
# EPOCH[11] - STEP[110]
# Generator_loss:1.1657
# L1_loss:0.1420
# Discriminator_loss:0.6941
#
# EPOCH[11] - STEP[120]
# Generator_loss:1.4252
# L1_loss:0.1675
# Discriminator_loss:0.4813
#
# EPOCH[11] - STEP[130]
# Generator_loss:1.8975
# L1_loss:0.1580
# Discriminator_loss:0.9828
#
# EPOCH[11] - STEP[140]
# Generator_loss:3.0513
# L1_loss:0.1789
# Discriminator_loss:0.5355
#
# EPOCH[11] - STEP[150]
# Generator_loss:1.7333
# L1_loss:0.1672
# Discriminator_loss:0.8932
#
# EPOCH[11] - STEP[160]
# Generator_loss:0.4030
# L1_loss:0.1781
# Discriminator_loss:1.5018
#
# EPOCH[11] - STEP[170]
# Generator_loss:1.9289
# L1_loss:0.1643
# Discriminator_loss:0.4175
#
# EPOCH[11] - STEP[180]
# Generator_loss:0.1191
# L1_loss:0.1811
# Discriminator_loss:2.9453
#
# EPOCH[11] - STEP[190]
# Generator_loss:0.5718
# L1_loss:0.1799
# Discriminator_loss:1.0089
#
# EPOCH[11] - STEP[200]
# Generator_loss:1.4927
# L1_loss:0.2394
# Discriminator_loss:0.4679
#
# EPOCH[11] - STEP[210]
# Generator_loss:2.8259
# L1_loss:0.1701
# Discriminator_loss:1.2328
#
# EPOCH[11] - STEP[220]
# Generator_loss:0.7577
# L1_loss:0.1643
# Discriminator_loss:1.1703
#
# EPOCH[11] - STEP[230]
# Generator_loss:1.1013
# L1_loss:0.1524
# Discriminator_loss:0.5841
#
# EPOCH[11] - STEP[240]
# Generator_loss:0.6636
# L1_loss:0.1693
# Discriminator_loss:0.9553
#
# EPOCH[11] - STEP[250]
# Generator_loss:3.3959
# L1_loss:0.2276
# Discriminator_loss:0.7444
#
# EPOCH[12] - STEP[10]
# Generator_loss:3.4100
# L1_loss:0.1463
# Discriminator_loss:1.4863
#
# EPOCH[12] - STEP[20]
# Generator_loss:1.4467
# L1_loss:0.1845
# Discriminator_loss:1.2098
#
# EPOCH[12] - STEP[30]
# Generator_loss:0.6043
# L1_loss:0.1526
# Discriminator_loss:1.4869
#
# EPOCH[12] - STEP[40]
# Generator_loss:1.2283
# L1_loss:0.1544
# Discriminator_loss:1.0468
#
# EPOCH[12] - STEP[50]
# Generator_loss:1.1313
# L1_loss:0.1514
# Discriminator_loss:0.7403
#
# EPOCH[12] - STEP[60]
# Generator_loss:2.6606
# L1_loss:0.1889
# Discriminator_loss:1.1093
#
# EPOCH[12] - STEP[70]
# Generator_loss:1.9860
# L1_loss:0.1977
# Discriminator_loss:0.6690
#
# EPOCH[12] - STEP[80]
# Generator_loss:2.1441
# L1_loss:0.1863
# Discriminator_loss:0.5713
#
# EPOCH[12] - STEP[90]
# Generator_loss:2.5247
# L1_loss:0.1621
# Discriminator_loss:1.0576
#
# EPOCH[12] - STEP[100]
# Generator_loss:1.5368
# L1_loss:0.1666
# Discriminator_loss:0.6657
#
# EPOCH[12] - STEP[110]
# Generator_loss:3.1612
# L1_loss:0.1773
# Discriminator_loss:1.1039
#
# EPOCH[12] - STEP[120]
# Generator_loss:1.6774
# L1_loss:0.1369
# Discriminator_loss:0.7616
#
# EPOCH[12] - STEP[130]
# Generator_loss:2.6161
# L1_loss:0.1661
# Discriminator_loss:1.1890
#
# EPOCH[12] - STEP[140]
# Generator_loss:1.9575
# L1_loss:0.1672
# Discriminator_loss:0.4679
#
# EPOCH[12] - STEP[150]
# Generator_loss:1.4825
# L1_loss:0.1471
# Discriminator_loss:0.9147
#
# EPOCH[12] - STEP[160]
# Generator_loss:0.6092
# L1_loss:0.1828
# Discriminator_loss:1.0683
#
# EPOCH[12] - STEP[170]
# Generator_loss:0.7086
# L1_loss:0.1986
# Discriminator_loss:0.8362
#
# EPOCH[12] - STEP[180]
# Generator_loss:1.5223
# L1_loss:0.1845
# Discriminator_loss:0.4508
#
# EPOCH[12] - STEP[190]
# Generator_loss:1.7853
# L1_loss:0.1898
# Discriminator_loss:0.4985
#
# EPOCH[12] - STEP[200]
# Generator_loss:1.6631
# L1_loss:0.1741
# Discriminator_loss:0.4874
#
# EPOCH[12] - STEP[210]
# Generator_loss:1.2965
# L1_loss:0.1569
# Discriminator_loss:1.1120
#
# EPOCH[12] - STEP[220]
# Generator_loss:2.4894
# L1_loss:0.1423
# Discriminator_loss:0.9760
#
# EPOCH[12] - STEP[230]
# Generator_loss:2.5735
# L1_loss:0.1792
# Discriminator_loss:0.2645
#
# EPOCH[12] - STEP[240]
# Generator_loss:0.6295
# L1_loss:0.1449
# Discriminator_loss:1.4738
#
# EPOCH[12] - STEP[250]
# Generator_loss:2.4165
# L1_loss:0.1814
# Discriminator_loss:0.5615
#
# EPOCH[13] - STEP[10]
# Generator_loss:2.2815
# L1_loss:0.1722
# Discriminator_loss:0.4103
#
# EPOCH[13] - STEP[20]
# Generator_loss:1.6447
# L1_loss:0.1363
# Discriminator_loss:1.2630
#
# EPOCH[13] - STEP[30]
# Generator_loss:2.4077
# L1_loss:0.1682
# Discriminator_loss:0.6622
#
# EPOCH[13] - STEP[40]
# Generator_loss:1.9126
# L1_loss:0.1370
# Discriminator_loss:0.4653
#
# EPOCH[13] - STEP[50]
# Generator_loss:2.7308
# L1_loss:0.1869
# Discriminator_loss:0.3580
#
# EPOCH[13] - STEP[60]
# Generator_loss:0.1155
# L1_loss:0.1941
# Discriminator_loss:2.6063
#
# EPOCH[13] - STEP[70]
# Generator_loss:2.1174
# L1_loss:0.1510
# Discriminator_loss:0.7555
#
# EPOCH[13] - STEP[80]
# Generator_loss:1.5627
# L1_loss:0.1686
# Discriminator_loss:0.6945
#
# EPOCH[13] - STEP[90]
# Generator_loss:2.8783
# L1_loss:0.1862
# Discriminator_loss:0.7066
#
# EPOCH[13] - STEP[100]
# Generator_loss:2.0294
# L1_loss:0.1517
# Discriminator_loss:0.4152
#
# EPOCH[13] - STEP[110]
# Generator_loss:1.1346
# L1_loss:0.1790
# Discriminator_loss:0.7315
#
# EPOCH[13] - STEP[120]
# Generator_loss:2.2101
# L1_loss:0.1585
# Discriminator_loss:0.6948
#
# EPOCH[13] - STEP[130]
# Generator_loss:1.2543
# L1_loss:0.1777
# Discriminator_loss:0.6005
#
# EPOCH[13] - STEP[140]
# Generator_loss:2.5138
# L1_loss:0.1642
# Discriminator_loss:0.7005
#
# EPOCH[13] - STEP[150]
# Generator_loss:1.2497
# L1_loss:0.1400
# Discriminator_loss:0.8137
#
# EPOCH[13] - STEP[160]
# Generator_loss:1.1140
# L1_loss:0.1533
# Discriminator_loss:1.1250
#
# EPOCH[13] - STEP[170]
# Generator_loss:1.9362
# L1_loss:0.1667
# Discriminator_loss:0.4259
#
# EPOCH[13] - STEP[180]
# Generator_loss:0.7914
# L1_loss:0.2113
# Discriminator_loss:0.9595
#
# EPOCH[13] - STEP[190]
# Generator_loss:1.8450
# L1_loss:0.1800
# Discriminator_loss:0.4828
#
# EPOCH[13] - STEP[200]
# Generator_loss:0.6471
# L1_loss:0.1462
# Discriminator_loss:0.9774
#
# EPOCH[13] - STEP[210]
# Generator_loss:1.5653
# L1_loss:0.2023
# Discriminator_loss:0.4299
#
# EPOCH[13] - STEP[220]
# Generator_loss:0.9915
# L1_loss:0.1895
# Discriminator_loss:0.9731
#
# EPOCH[13] - STEP[230]
# Generator_loss:1.5426
# L1_loss:0.1977
# Discriminator_loss:0.3370
#
# EPOCH[13] - STEP[240]
# Generator_loss:0.6320
# L1_loss:0.1423
# Discriminator_loss:0.9956
#
# EPOCH[13] - STEP[250]
# ...
# L1_loss:0.1223
# Discriminator_loss:0.8080
#
# EPOCH[96] - STEP[190]
# Generator_loss:5.0481
# L1_loss:0.1372
# Discriminator_loss:0.1309
#
# EPOCH[96] - STEP[200]
# Generator_loss:0.9037
# L1_loss:0.1201
# Discriminator_loss:0.9684
#
# EPOCH[96] - STEP[210]
# Generator_loss:3.1649
# L1_loss:0.1147
# Discriminator_loss:0.4967
#
# EPOCH[96] - STEP[220]
# Generator_loss:2.3157
# L1_loss:0.1350
# Discriminator_loss:0.3739
#
# EPOCH[96] - STEP[230]
# Generator_loss:3.5291
# L1_loss:0.0929
# Discriminator_loss:0.9866
#
# EPOCH[96] - STEP[240]
# Generator_loss:6.6020
# L1_loss:0.1429
# Discriminator_loss:0.1529
#
# EPOCH[96] - STEP[250]
# Generator_loss:2.9826
# L1_loss:0.1197
# Discriminator_loss:0.2676
#
# EPOCH[97] - STEP[10]
# Generator_loss:2.8725
# L1_loss:0.1273
# Discriminator_loss:0.1610
#
# EPOCH[97] - STEP[20]
# Generator_loss:3.2958
# L1_loss:0.1602
# Discriminator_loss:0.2707
#
# EPOCH[97] - STEP[30]
# Generator_loss:4.9032
# L1_loss:0.1212
# Discriminator_loss:0.7198
#
# EPOCH[97] - STEP[40]
# Generator_loss:2.6707
# L1_loss:0.1289
# Discriminator_loss:0.1870
#
# EPOCH[97] - STEP[50]
# Generator_loss:3.5596
# L1_loss:0.1229
# Discriminator_loss:0.1313
#
# EPOCH[97] - STEP[60]
# Generator_loss:3.1956
# L1_loss:0.1485
# Discriminator_loss:0.0868
#
# EPOCH[97] - STEP[70]
# Generator_loss:0.8624
# L1_loss:0.1321
# Discriminator_loss:1.0881
#
# EPOCH[97] - STEP[80]
# Generator_loss:0.6623
# L1_loss:0.1390
# Discriminator_loss:1.2747
#
# EPOCH[97] - STEP[90]
# Generator_loss:0.7449
# L1_loss:0.1429
# Discriminator_loss:1.2494
#
# EPOCH[97] - STEP[100]
# Generator_loss:1.7899
# L1_loss:0.1286
# Discriminator_loss:0.3575
#
# EPOCH[97] - STEP[110]
# Generator_loss:7.2776
# L1_loss:0.1561
# Discriminator_loss:0.1560
#
# EPOCH[97] - STEP[120]
# Generator_loss:4.6622
# L1_loss:0.1200
# Discriminator_loss:0.0580
#
# EPOCH[97] - STEP[130]
# Generator_loss:2.5838
# L1_loss:0.1305
# Discriminator_loss:0.2004
#
# EPOCH[97] - STEP[140]
# Generator_loss:5.5603
# L1_loss:0.1036
# Discriminator_loss:0.5742
#
# EPOCH[97] - STEP[150]
# Generator_loss:2.7202
# L1_loss:0.1846
# Discriminator_loss:0.1525
#
# EPOCH[97] - STEP[160]
# Generator_loss:4.9434
# L1_loss:0.1273
# Discriminator_loss:0.0442
#
# EPOCH[97] - STEP[170]
# Generator_loss:5.1171
# L1_loss:0.1321
# Discriminator_loss:0.0903
#
# EPOCH[97] - STEP[180]
# Generator_loss:4.7315
# L1_loss:0.1886
# Discriminator_loss:0.0255
#
# EPOCH[97] - STEP[190]
# Generator_loss:7.4114
# L1_loss:0.1522
# Discriminator_loss:0.1810
#
# EPOCH[97] - STEP[200]
# Generator_loss:0.6212
# L1_loss:0.1207
# Discriminator_loss:1.5321
#
# EPOCH[97] - STEP[210]
# Generator_loss:1.2780
# L1_loss:0.1216
# Discriminator_loss:0.6778
#
# EPOCH[97] - STEP[220]
# Generator_loss:4.2765
# L1_loss:0.1491
# Discriminator_loss:0.1011
#
# EPOCH[97] - STEP[230]
# Generator_loss:5.5527
# L1_loss:0.1381
# Discriminator_loss:0.0589
#
# EPOCH[97] - STEP[240]
# Generator_loss:3.0220
# L1_loss:0.1278
# Discriminator_loss:0.1301
#
# EPOCH[97] - STEP[250]
# Generator_loss:5.2722
# L1_loss:0.1325
# Discriminator_loss:0.0858
#
# EPOCH[98] - STEP[10]
# Generator_loss:3.7685
# L1_loss:0.1322
# Discriminator_loss:0.4200
#
# EPOCH[98] - STEP[20]
# Generator_loss:3.7940
# L1_loss:0.1231
# Discriminator_loss:0.6003
#
# EPOCH[98] - STEP[30]
# Generator_loss:4.6565
# L1_loss:0.1360
# Discriminator_loss:0.3132
#
# EPOCH[98] - STEP[40]
# Generator_loss:1.0639
# L1_loss:0.1341
# Discriminator_loss:0.7725
#
# EPOCH[98] - STEP[50]
# Generator_loss:2.9518
# L1_loss:0.1372
# Discriminator_loss:0.2149
#
# EPOCH[98] - STEP[60]
# Generator_loss:0.5302
# L1_loss:0.1598
# Discriminator_loss:1.3653
#
# EPOCH[98] - STEP[70]
# Generator_loss:2.1663
# L1_loss:0.0988
# Discriminator_loss:0.6704
#
# EPOCH[98] - STEP[80]
# Generator_loss:7.7111
# L1_loss:0.1450
# Discriminator_loss:0.4764
#
# EPOCH[98] - STEP[90]
# Generator_loss:6.8079
# L1_loss:0.1409
# Discriminator_loss:0.0570
#
# EPOCH[98] - STEP[100]
# Generator_loss:6.3565
# L1_loss:0.1163
# Discriminator_loss:0.7763
#
# EPOCH[98] - STEP[110]
# Generator_loss:4.5037
# L1_loss:0.1198
# Discriminator_loss:0.5315
#
# EPOCH[98] - STEP[120]
# Generator_loss:1.4363
# L1_loss:0.1521
# Discriminator_loss:0.5734
#
# EPOCH[98] - STEP[130]
# Generator_loss:4.3176
# L1_loss:0.1309
# Discriminator_loss:0.2008
#
# EPOCH[98] - STEP[140]
# Generator_loss:3.4886
# L1_loss:0.1966
# Discriminator_loss:0.1580
#
# EPOCH[98] - STEP[150]
# Generator_loss:3.3228
# L1_loss:0.1442
# Discriminator_loss:0.1475
#
# EPOCH[98] - STEP[160]
# Generator_loss:2.2888
# L1_loss:0.1332
# Discriminator_loss:0.2721
#
# EPOCH[98] - STEP[170]
# Generator_loss:4.1657
# L1_loss:0.1295
# Discriminator_loss:0.0862
#
# EPOCH[98] - STEP[180]
# Generator_loss:3.4540
# L1_loss:0.1148
# Discriminator_loss:0.1556
#
# EPOCH[98] - STEP[190]
# Generator_loss:4.5996
# L1_loss:0.1490
# Discriminator_loss:0.1130
#
# EPOCH[98] - STEP[200]
# Generator_loss:3.5747
# L1_loss:0.1267
# Discriminator_loss:0.0791
#
# EPOCH[98] - STEP[210]
# Generator_loss:5.5760
# L1_loss:0.1155
# Discriminator_loss:0.6054
#
# EPOCH[98] - STEP[220]
# Generator_loss:4.8003
# L1_loss:0.1255
# Discriminator_loss:0.6462
#
# EPOCH[98] - STEP[230]
# Generator_loss:4.5370
# L1_loss:0.1195
# Discriminator_loss:0.0477
#
# EPOCH[98] - STEP[240]
# Generator_loss:2.2066
# L1_loss:0.1202
# Discriminator_loss:0.3170
#
# EPOCH[98] - STEP[250]
# Generator_loss:1.6678
# L1_loss:0.1077
# Discriminator_loss:0.3864
#
# EPOCH[99] - STEP[10]
# Generator_loss:0.7509
# L1_loss:0.1376
# Discriminator_loss:1.1986
#
# EPOCH[99] - STEP[20]
# Generator_loss:2.5940
# L1_loss:0.1390
# Discriminator_loss:0.2543
#
# EPOCH[99] - STEP[30]
# Generator_loss:1.9504
# L1_loss:0.1338
# Discriminator_loss:0.3412
#
# EPOCH[99] - STEP[40]
# Generator_loss:6.3713
# L1_loss:0.1366
# Discriminator_loss:0.0535
#
# EPOCH[99] - STEP[50]
# Generator_loss:2.3374
# L1_loss:0.0969
# Discriminator_loss:0.2890
#
# EPOCH[99] - STEP[60]
# Generator_loss:7.8635
# L1_loss:0.1402
# Discriminator_loss:0.1300
#
# EPOCH[99] - STEP[70]
# Generator_loss:3.0899
# L1_loss:0.1377
# Discriminator_loss:0.6160
#
# EPOCH[99] - STEP[80]
# Generator_loss:2.9616
# L1_loss:0.1957
# Discriminator_loss:0.1818
#
# EPOCH[99] - STEP[90]
# Generator_loss:7.6197
# L1_loss:0.1831
# Discriminator_loss:0.0111
#
# EPOCH[99] - STEP[100]
# Generator_loss:6.6129
# L1_loss:0.1435
# Discriminator_loss:0.0859
#
# EPOCH[99] - STEP[110]
# Generator_loss:3.6950
# L1_loss:0.1283
# Discriminator_loss:0.2141
#
# EPOCH[99] - STEP[120]
# Generator_loss:2.3971
# L1_loss:0.1015
# Discriminator_loss:0.3364
#
# EPOCH[99] - STEP[130]
# Generator_loss:3.8279
# L1_loss:0.1345
# Discriminator_loss:0.0760
#
# EPOCH[99] - STEP[140]
# Generator_loss:5.3125
# L1_loss:0.1046
# Discriminator_loss:0.3366
#
# EPOCH[99] - STEP[150]
# Generator_loss:4.0749
# L1_loss:0.1684
# Discriminator_loss:0.0524
#
# EPOCH[99] - STEP[160]
# Generator_loss:2.8713
# L1_loss:0.1059
# Discriminator_loss:0.5121
#
# EPOCH[99] - STEP[170]
# Generator_loss:4.2911
# L1_loss:0.1334
# Discriminator_loss:0.0754
#
# EPOCH[99] - STEP[180]
# Generator_loss:6.6041
# L1_loss:0.1573
# Discriminator_loss:0.1807
#
# EPOCH[99] - STEP[190]
# Generator_loss:6.9493
# L1_loss:0.1409
# Discriminator_loss:0.0701
#
# EPOCH[99] - STEP[200]
# Generator_loss:1.8555
# L1_loss:0.1117
# Discriminator_loss:0.4767
#
# EPOCH[99] - STEP[210]
# Generator_loss:5.4290
# L1_loss:0.1260
# Discriminator_loss:0.0658
#
# EPOCH[99] - STEP[220]
# Generator_loss:3.3157
# L1_loss:0.1489
# Discriminator_loss:0.1237
#
# EPOCH[99] - STEP[230]
# Generator_loss:5.0741
# L1_loss:0.1388
# Discriminator_loss:0.0916
#
# EPOCH[99] - STEP[240]
# Generator_loss:5.9954
# L1_loss:0.1095
# Discriminator_loss:0.3147
#
# EPOCH[99] - STEP[250]
# Generator_loss:2.6672
# L1_loss:0.1335
# Discriminator_loss:0.2433
#
# EPOCH[100] - STEP[10]
# Generator_loss:6.1830
# L1_loss:0.1162
# Discriminator_loss:0.0741
#
# EPOCH[100] - STEP[20]
# Generator_loss:1.8929
# L1_loss:0.1354
# Discriminator_loss:0.3334
#
# EPOCH[100] - STEP[30]
# Generator_loss:1.3167
# L1_loss:0.1600
# Discriminator_loss:0.6770
#
# EPOCH[100] - STEP[40]
# Generator_loss:3.9825
# L1_loss:0.1348
# Discriminator_loss:0.1555
#
# EPOCH[100] - STEP[50]
# Generator_loss:4.9061
# L1_loss:0.1384
# Discriminator_loss:0.1813
#
# EPOCH[100] - STEP[60]
# Generator_loss:3.9505
# L1_loss:0.1639
# Discriminator_loss:0.0776
#
# EPOCH[100] - STEP[70]
# Generator_loss:5.1684
# L1_loss:0.1701
# Discriminator_loss:0.0587
#
# EPOCH[100] - STEP[80]
# Generator_loss:7.5019
# L1_loss:0.1438
# Discriminator_loss:0.5352
#
# EPOCH[100] - STEP[90]
# Generator_loss:1.5839
# L1_loss:0.1140
# Discriminator_loss:0.4283
#
# EPOCH[100] - STEP[100]
# Generator_loss:2.2313
# L1_loss:0.1253
# Discriminator_loss:0.2721
#
# EPOCH[100] - STEP[110]
# Generator_loss:4.0340
# L1_loss:0.1197
# Discriminator_loss:0.3784
#
# EPOCH[100] - STEP[120]
# Generator_loss:1.7111
# L1_loss:0.1510
# Discriminator_loss:0.3637
#
# EPOCH[100] - STEP[130]
# Generator_loss:5.8761
# L1_loss:0.1142
# Discriminator_loss:1.8092
#
# EPOCH[100] - STEP[140]
# Generator_loss:4.5164
# L1_loss:0.1334
# Discriminator_loss:1.0927
#
# EPOCH[100] - STEP[150]
# Generator_loss:4.8706
# L1_loss:0.1332
# Discriminator_loss:0.4891
#
# EPOCH[100] - STEP[160]
# Generator_loss:7.2658
# L1_loss:0.1309
# Discriminator_loss:0.1500
#
# EPOCH[100] - STEP[170]
# Generator_loss:1.4647
# L1_loss:0.1294
# Discriminator_loss:0.9153
#
# EPOCH[100] - STEP[180]
# Generator_loss:6.5972
# L1_loss:0.1439
# Discriminator_loss:1.2777
#
# EPOCH[100] - STEP[190]
# Generator_loss:1.5915
# L1_loss:0.1906
# Discriminator_loss:0.5815
#
# EPOCH[100] - STEP[200]
# Generator_loss:4.2067
# L1_loss:0.1274
# Discriminator_loss:0.7459
#
# EPOCH[100] - STEP[210]
# Generator_loss:1.6538
# L1_loss:0.1188
# Discriminator_loss:0.9556
#
# EPOCH[100] - STEP[220]
# Generator_loss:3.6574
# L1_loss:0.1273
# Discriminator_loss:0.1324
#
# EPOCH[100] - STEP[230]
# Generator_loss:4.6654
# L1_loss:0.1278
# Discriminator_loss:0.3049
#
# EPOCH[100] - STEP[240]
# Generator_loss:4.9970
# L1_loss:0.1451
# Discriminator_loss:0.0916
#
# EPOCH[100] - STEP[250]
# Generator_loss:3.3753
# L1_loss:0.1416
# Discriminator_loss:0.2080

# %%
test_ind = 1

f = val_path + os.listdir(val_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))

# %%
test_ind = 2

f = val_path + os.listdir(val_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))
